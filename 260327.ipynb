# %%
height1 = float(input("학생 1의 키(cm)를 입력하세요: "))
height2 = float(input("학생 2의 키(cm)를 입력하세요: "))
if height1>height2:
  print("첫번째 학생이 더 크다.")
else:
  print("두번째 학생이 더 크다")
# Out:
# 학생 1의 키(cm)를 입력하세요: 170
# 학생 2의 키(cm)를 입력하세요: 170
# 두번째 학생이 더 크다

# %%
height1 = float(input("학생 1의 키(cm)를 입력하세요: "))
height2 = float(input("학생 2의 키(cm)를 입력하세요: "))
if height1==height2:
  print("두 학생의 키는 같다.")
if height1>height2:
  print("첫번째 학생이 더 크다.")
if height1<height2:
  print("두번째 학생이 더 크다.")
# Out:
# 학생 1의 키(cm)를 입력하세요: 170
# 학생 2의 키(cm)를 입력하세요: 180
# 두번째 학생이 더 크다.

# %%
height1 = float(input("학생 1의 키(cm)를 입력하세요: "))
height2 = float(input("학생 2의 키(cm)를 입력하세요: "))
if height1==height2:
  print("두 학생의 키는 같다.")
elif height1>height2:
  print("첫번째 학생이 더 크다.")
else:
  print("두번째 학생이 더 크다.")
# Out:
# 학생 1의 키(cm)를 입력하세요: 170
# 학생 2의 키(cm)를 입력하세요: 180
# 두번째 학생이 더 크다.

# %%
score = float(input("점수를 입력하시오:"))
if 100>=score>=90:
  print("A")
elif 90>score>=80:
  print("B")
elif 80>score>=70:
  print("C")
else:
  print("D")
# Out:
# 점수를 입력하시오:80.5
# B

# %%
import random

dice1=random.randint(1,6)
dice2=random.randint(1,6)

print(f'주사위1:{dice1}')
print(f'주사위2:{dice2}')
# Out:
# 주사위1:6
# 주사위2:5

# %%
import random

dice1=random.randint(1,6)
dice2=random.randint(1,6)

print(f'주사위1:{dice1}')
print(f'주사위2:{dice2}')

if
# Out:
# 주사위1:1
# 주사위2:3

# %%
y=int(input("연도를 입력하시오 : "))
if(y%400==0)or(y%4==0 and y%100!=0):
  print("윤년")
else:
  print("평년")
# Out:
# 연도를 입력하시오 : 2024
# 윤년

# %%
import random

#가위1 바위2 보3

player1=random.randint(1,3)
player2=random.randint(1,3)

print(f'player1:{player1}')
print(f'player2:{player2}')

if player1==player2:
  print("무승부")
elif player1==1 and player2==3:
  print("player1이 이겼습니다.")
elif player1==2 and player2==1:
  print("player1이 이겼습니다.")
elif player1==3 and player2==2:
  print("player1이 이겼습니다.")
else:
  print("player2가 이겼습니다.")
# Out:
# player1:3
# player2:1
# player2가 이겼습니다.

# %%
def hello():
  print("안녕하세요")

# %%
hello()
# Out:
# 안녕하세요

# %%
def hello(irum,age):
  age+=1
  print(f'{irum}님 {age}세 안녕하세요')
  return age

# %%
age1=hello('김리원',23)
print(age1)
# Out:
# 김리원님 24세 안녕하세요
# 24
